# %% [markdown]
# # This is an Analysis of mental health from a survey given by Kaggle on people in tech
#
# Data was taken from https://www.kaggle.com/osmi/mental-health-in-tech-survey/version/3

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
survey = pd.read_csv("data/survey.csv")

# %%
fig, ax = plt.subplots()
for key, value in survey.groupby('Gender'):
    ax.bar(index, value.shape[0], color='b',label=key)

ax.set_xlabel('Group')
ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.legend()

plt.show()

# %%
ages = []

for key, data in survey.groupby('Age'):
    data.
# Out:
#                Timestamp   Age Gender         Country state self_employed  \
# 715  2014-08-28 10:07:53 -1726   male  United Kingdom   NaN            No
#
#     family_history treatment work_interfere no_employees   ...     \
# 715             No       Yes      Sometimes       26-100   ...
#
#                   leave mental_health_consequence phys_health_consequence  \
# 715  Somewhat difficult                       Yes                      No
#
#     coworkers supervisor mental_health_interview phys_health_interview  \
# 715        No         No                      No                 Maybe
#
#     mental_vs_physical obs_consequence comments
# 715         Don't know              No      NaN
#
# [1 rows x 27 columns]
#                Timestamp  Age Gender        Country state self_employed  \
# 143  2014-08-27 12:39:14  -29   Male  United States    MN            No
#
#     family_history treatment work_interfere    no_employees   ...     \
# ...
